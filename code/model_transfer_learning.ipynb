# %% [markdown]
# <a href="https://colab.research.google.com/github/amaye15/CanineNet/blob/main/code/model_transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install

# %%
# %pip install huggingface_hub torchview mlflow datasets==2.15.0 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 40.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 36.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 22.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 17.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.4 MB/s eta 0:00:00

# %% [markdown]
# # HuggingFace Login

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# # Set Up

# %%
import io
import os
import cv2
import datasets
import torch
import torchview
import pyarrow_hotfix
import mlflow
import mlflow.pytorch
import graphviz
import uuid

import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import torch.optim as optim

from PIL import Image
from torchvision.transforms import v2
from torch.utils.data import DataLoader
from datasets import load_dataset, ClassLabel, Value
from functools import partial
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix
from transformers import ViTFeatureExtractor, ViTForImageClassification
from transformers import AdamW, get_linear_schedule_with_warmup
from torchview import draw_graph


pyarrow_hotfix.uninstall()
graphviz.set_jupyter_format('png')

os.environ['MLFLOW_TRACKING_USERNAME'] = "andrewmayes14"
os.environ['MLFLOW_TRACKING_PASSWORD'] = "ccb096afadd26486a787461f3495219662998c4b"
os.environ['MLFLOW_TRACKING_PROJECTNAME'] = "mlflow"

mlflow.set_tracking_uri(f'https://dagshub.com/' + os.environ['MLFLOW_TRACKING_USERNAME']
                         + '/' + os.environ['MLFLOW_TRACKING_PROJECTNAME'] + '.mlflow')

mlflow.set_experiment("CanineNetV2")

# Constants
DATASET = "Alanox/stanford-dogs"
REMOVE_COLS_V1 = ["name", "annotations"]
REMOVE_COLS_V2 = ["name", "annotations", "image"]
NAME_COLS = {"index": "label", 0: "count"}
SPLIT = 0.2

# Load the dataset
dataset = datasets.load_dataset(DATASET, split="full").remove_columns(REMOVE_COLS_V1)# .train_test_split(test_size=SPLIT, stratify_by_column="target") #, streaming=True)

### This is a bit of a work aroound to get even class seperation
target_df = datasets.load_dataset(DATASET, split="full").remove_columns(REMOVE_COLS_V2).to_pandas().value_counts().reset_index().reset_index().rename(columns=NAME_COLS)
# Convert the target column to a list and find unique classes
unique_classes = set(target_df['target'])
# Define the ClassLabel feature
class_label_feature = ClassLabel(num_classes=len(unique_classes), names=list(unique_classes), id = list(range(len(unique_classes))))
# Update the dataset schema to use ClassLabel for the target column
dataset = dataset.cast_column('target', class_label_feature)
###

# Split Dataset
dataset = dataset.train_test_split(test_size=SPLIT, stratify_by_column = "target")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.14k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/954 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/740M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.19M [00:00<?, ?B/s]
# Generating full split: 0 examples [00:00, ? examples/s]
# Casting the dataset:   0%|          | 0/20580 [00:00<?, ? examples/s]

# %% [markdown]
# # Model

# %%
# Load the model and the feature extractor
feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224')

model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224',
                                                  num_labels = len(target_df["label"].tolist()),
                                                  id2label = dict(zip(dataset["train"].features["target"].id, dataset["train"].features["target"].names)),
                                                  label2id = dict(zip(dataset["train"].features["target"].names, dataset["train"].features["target"].id)),
                                                  ignore_mismatched_sizes=True)
# Out:
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([120]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([120, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def transforms(examples, transformation: bool = False, ops: int = 10):
  if transformation:
    transformation = v2.Compose([v2.RandAugment(num_ops = ops)])
    examples["image"] = [feature_extractor(transformation(image), return_tensors = "pt")["pixel_values"].squeeze() for image in examples["image"]]
  else:
    examples["image"] = [feature_extractor(image, return_tensors = "pt")["pixel_values"].squeeze() for image in examples["image"]]
  return examples

# %% [markdown]
# # Fine Tune - No Transformation

# %%
# Start run
run = mlflow.start_run()

# Train Config
EPOCHS = 10
LEARNING_RATE = 5e-5
BATCH_SIZE = 64
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
TRANSFORM = False

# Criteria & Optimiser
criterion = nn.CrossEntropyLoss()
#optimizer = optim.Adam(model.parameters(), lr = LEARNING_RATE)
optimizer = AdamW(model.parameters(), lr=LEARNING_RATE)
num_training_steps = EPOCHS * dataset["train"].num_rows
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=num_training_steps * 0.01, num_training_steps=num_training_steps)

# Device
model.to(DEVICE)

# Log parameters
mlflow.log_param("epochs", EPOCHS)
mlflow.log_param("learning_rate", LEARNING_RATE)
mlflow.log_param("batch_size", BATCH_SIZE)
mlflow.log_param("image_transformation", TRANSFORM)
# mlflow.log_param("layers", len(convLayers))

train_step = 0
test_step = 0

if TRANSFORM:
  # Transformation and dataset settings as before
  dataset["train"].set_transform(partial(transforms, transformation = True,))
  dataset["test"].set_transform(transforms)
else:
  # Transformation and dataset settings as before
  dataset.set_transform(transforms)

# Model, Criterion, Optimizer setup remains the same
for epoch in range(EPOCHS):

  first_epoch = (epoch == 0)
  last_epoch = (epoch == (EPOCHS - 1))

  # Train
  print("Train")
  model.train()
  for batch in DataLoader(dataset["train"], batch_size=BATCH_SIZE, shuffle=True):
      optimizer.zero_grad()
      output = model(batch["image"].float().to(DEVICE))
      loss = criterion(output.logits, batch["target"].to(DEVICE))
      loss.backward()
      optimizer.step()
      scheduler.step()

      train_step += 1

      # Compute training metrics
      train_accuracy = accuracy_score(batch["target"].numpy(), output.logits.argmax(dim=1).cpu().numpy())
      train_precision, train_recall, train_f1, train_support = precision_recall_fscore_support(batch["target"].numpy(),
                                                                                               output.logits.argmax(dim=1).cpu().numpy(),
                                                                                               average='macro',
                                                                                               zero_division = 0.0)
      # Log training metrics
      mlflow.log_metrics({'train_loss': loss.item(),
                          'train_accuracy': train_accuracy,
                          'train_precision': train_precision,
                          'train_recall': train_recall,
                          'train_f1': train_f1,}, step = train_step)

      print({'train_loss': loss.item(),
              'train_accuracy': train_accuracy,
              'train_precision': train_precision,
              'train_recall': train_recall,
              'train_f1': train_f1,})

  # Test
  print("Test")
  model.eval()

  if last_epoch:
    all_test_labels = []
    all_test_preds = []

  with torch.no_grad():
      for batch in DataLoader(dataset["test"], batch_size=BATCH_SIZE, shuffle=False):
          output = model(batch["image"].squeeze(dim=0).float().to(DEVICE))
          loss = criterion(output.logits, batch["target"].to(DEVICE))

          if last_epoch:
            all_test_labels.extend(batch["target"].numpy().tolist())
            all_test_preds.extend(output.logits.argmax(dim=1).cpu().numpy().tolist())

          test_step += 1

          # Compute testing metrics
          test_accuracy = accuracy_score(batch["target"].numpy(), output.logits.argmax(dim=1).cpu().numpy())
          test_precision, test_recall, test_f1, test_support = precision_recall_fscore_support(batch["target"].numpy(),
                                                                                               output.logits.argmax(dim=1).cpu().numpy(),
                                                                                               average='macro',
                                                                                               zero_division = 0.0)
          # Log testing metrics
          mlflow.log_metrics({'test_loss': loss.item(),
                              'test_accuracy': test_accuracy,
                              'test_precision': test_precision,
                              'test_recall': test_recall,
                              'test_f1': test_f1,}, step = test_step)

          print({'test_loss': loss.item(),
                              'test_accuracy': test_accuracy,
                              'test_precision': test_precision,
                              'test_recall': test_recall,
                              'test_f1': test_f1,})
  if last_epoch:
    id2labels = dict(zip(dataset["train"].features["target"].id, dataset["train"].features["target"].names))
    sorted_ids = sorted(id2labels.keys())
    class_names = [id2labels[i] for i in sorted_ids]

    # Log Confusion Matrix as an artifact
    cm = confusion_matrix(all_test_labels, all_test_preds)
    plt.figure(figsize=(30,21))
    sns.heatmap(cm, annot=False, xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Truth')
    plt.title(f'Confusion Matrix at Epoch {epoch}')
    plt.savefig("confusion_matrix.png")
    mlflow.log_artifact("confusion_matrix.png")

# End run
mlflow.end_run()
feature_extractor.push_to_hub("ViT-Standford-Dogs")
model.push_to_hub("ViT-Standford-Dogs")

# %% [markdown]
# # Fine Tune - Transformation

# %%
# Start run
run = mlflow.start_run()

# Train Config
EPOCHS = 10
LEARNING_RATE = 5e-5
BATCH_SIZE = 64
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
TRANSFORM = True

# Criteria & Optimiser
criterion = nn.CrossEntropyLoss()
#optimizer = optim.Adam(model.parameters(), lr = LEARNING_RATE)
optimizer = AdamW(model.parameters(), lr=LEARNING_RATE)
num_training_steps = EPOCHS * dataset["train"].num_rows
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=num_training_steps * 0.01, num_training_steps=num_training_steps)

# Device
model.to(DEVICE)

# Log parameters
mlflow.log_param("epochs", EPOCHS)
mlflow.log_param("learning_rate", LEARNING_RATE)
mlflow.log_param("batch_size", BATCH_SIZE)
mlflow.log_param("image_transformation", TRANSFORM)
# mlflow.log_param("layers", len(convLayers))

train_step = 0
test_step = 0

if TRANSFORM:
  # Transformation and dataset settings as before
  dataset["train"].set_transform(partial(transforms, transformation = True,))
  dataset["test"].set_transform(transforms)
else:
  # Transformation and dataset settings as before
  dataset.set_transform(transforms)

# Model, Criterion, Optimizer setup remains the same
for epoch in range(EPOCHS):

  if TRANSFORM:
    # Transformation and dataset settings as before
    dataset["train"].set_transform(partial(transforms, transformation = True,))

  first_epoch = (epoch == 0)
  last_epoch = (epoch == (EPOCHS - 1))

  # Train
  print("Train")
  model.train()
  for batch in DataLoader(dataset["train"], batch_size=BATCH_SIZE, shuffle=True):
      optimizer.zero_grad()
      output = model(batch["image"].float().to(DEVICE))
      loss = criterion(output.logits, batch["target"].to(DEVICE))
      loss.backward()
      optimizer.step()
      scheduler.step()

      train_step += 1

      # Compute training metrics
      train_accuracy = accuracy_score(batch["target"].numpy(), output.logits.argmax(dim=1).cpu().numpy())
      train_precision, train_recall, train_f1, train_support = precision_recall_fscore_support(batch["target"].numpy(),
                                                                                               output.logits.argmax(dim=1).cpu().numpy(),
                                                                                               average='macro',
                                                                                               zero_division = 0.0)
      # Log training metrics
      mlflow.log_metrics({'train_loss': loss.item(),
                          'train_accuracy': train_accuracy,
                          'train_precision': train_precision,
                          'train_recall': train_recall,
                          'train_f1': train_f1,}, step = train_step)

      print({'train_loss': loss.item(),
              'train_accuracy': train_accuracy,
              'train_precision': train_precision,
              'train_recall': train_recall,
              'train_f1': train_f1,})

  # Test
  print("Test")
  model.eval()

  if last_epoch:
    all_test_labels = []
    all_test_preds = []

  with torch.no_grad():
      for batch in DataLoader(dataset["test"], batch_size=BATCH_SIZE, shuffle=False):
          output = model(batch["image"].squeeze(dim=0).float().to(DEVICE))
          loss = criterion(output.logits, batch["target"].to(DEVICE))

          if last_epoch:
            all_test_labels.extend(batch["target"].numpy().tolist())
            all_test_preds.extend(output.logits.argmax(dim=1).cpu().numpy().tolist())

          test_step += 1

          # Compute testing metrics
          test_accuracy = accuracy_score(batch["target"].numpy(), output.logits.argmax(dim=1).cpu().numpy())
          test_precision, test_recall, test_f1, test_support = precision_recall_fscore_support(batch["target"].numpy(),
                                                                                               output.logits.argmax(dim=1).cpu().numpy(),
                                                                                               average='macro',
                                                                                               zero_division = 0.0)
          # Log testing metrics
          mlflow.log_metrics({'test_loss': loss.item(),
                              'test_accuracy': test_accuracy,
                              'test_precision': test_precision,
                              'test_recall': test_recall,
                              'test_f1': test_f1,}, step = test_step)

          print({'test_loss': loss.item(),
                              'test_accuracy': test_accuracy,
                              'test_precision': test_precision,
                              'test_recall': test_recall,
                              'test_f1': test_f1,})
  if last_epoch:
    id2labels = dict(zip(dataset["train"].features["target"].id, dataset["train"].features["target"].names))
    sorted_ids = sorted(id2labels.keys())
    class_names = [id2labels[i] for i in sorted_ids]

    # Log Confusion Matrix as an artifact
    cm = confusion_matrix(all_test_labels, all_test_preds)
    plt.figure(figsize=(30,21))
    sns.heatmap(cm, annot=False, xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Truth')
    plt.title(f'Confusion Matrix at Epoch {epoch}')
    plt.savefig("confusion_matrix.png")
    mlflow.log_artifact("confusion_matrix.png")

# End run
mlflow.end_run()
feature_extractor.push_to_hub("ViT-Standford-Dogs")
model.push_to_hub("ViT-Standford-Dogs")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Train
# {'train_loss': 4.952563285827637, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 5.028340816497803, 'train_accuracy': 0.015625, 'train_precision': 0.00684931506849315, 'train_recall': 0.00684931506849315, 'train_f1': 0.00684931506849315}
# {'train_loss': 5.088619709014893, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.996757507324219, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.8988823890686035, 'train_accuracy': 0.015625, 'train_precision': 0.013513513513513514, 'train_recall': 0.013513513513513514, 'train_f1': 0.013513513513513514}
# {'train_loss': 4.9119720458984375, 'train_accuracy': 0.015625, 'train_precision': 0.006756756756756757, 'train_recall': 0.013513513513513514, 'train_f1': 0.009009009009009009}
# {'train_loss': 4.984621524810791, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 5.10111665725708, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.9203290939331055, 'train_accuracy': 0.03125, 'train_precision': 0.014492753623188406, 'train_recall': 0.014492753623188406, 'train_f1': 0.014492753623188406}
# {'train_loss': 5.046833038330078, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.927172660827637, 'train_accuracy': 0.015625, 'train_precision': 0.013157894736842105, 'train_recall': 0.013157894736842105, 'train_f1': 0.013157894736842105}
# {'train_loss': 4.91264009475708, 'train_accuracy': 0.015625, 'train_precision': 0.014925373134328358, 'train_recall': 0.014925373134328358, 'train_f1': 0.014925373134328358}
# {'train_loss': 4.9695658683776855, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.923183441162109, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.925317764282227, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.89021635055542, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.92147970199585, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.959342002868652, 'train_accuracy': 0.015625, 'train_precision': 0.007246376811594203, 'train_recall': 0.004830917874396135, 'train_f1': 0.005797101449275362}
# {'train_loss': 4.864232063293457, 'train_accuracy': 0.015625, 'train_precision': 0.0044444444444444444, 'train_recall': 0.013333333333333334, 'train_f1': 0.006666666666666667}
# {'train_loss': 5.037707805633545, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.836285591125488, 'train_accuracy': 0.015625, 'train_precision': 0.014084507042253521, 'train_recall': 0.0035211267605633804, 'train_f1': 0.005633802816901409}
# {'train_loss': 4.856603145599365, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.97418737411499, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.8092427253723145, 'train_accuracy': 0.015625, 'train_precision': 0.0125, 'train_recall': 0.0125, 'train_f1': 0.0125}
# {'train_loss': 4.894831657409668, 'train_accuracy': 0.015625, 'train_precision': 0.007352941176470588, 'train_recall': 0.014705882352941176, 'train_f1': 0.00980392156862745}
# {'train_loss': 5.016716480255127, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.8897175788879395, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.987294673919678, 'train_accuracy': 0.015625, 'train_precision': 0.004629629629629629, 'train_recall': 0.013888888888888888, 'train_f1': 0.006944444444444444}
# {'train_loss': 4.898613452911377, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.899900436401367, 'train_accuracy': 0.03125, 'train_precision': 0.02142857142857143, 'train_recall': 0.02142857142857143, 'train_f1': 0.019047619047619046}
# {'train_loss': 4.865692138671875, 'train_accuracy': 0.03125, 'train_precision': 0.02666666666666667, 'train_recall': 0.02666666666666667, 'train_f1': 0.02666666666666667}
# {'train_loss': 4.843056678771973, 'train_accuracy': 0.015625, 'train_precision': 0.014492753623188406, 'train_recall': 0.007246376811594203, 'train_f1': 0.00966183574879227}
# {'train_loss': 4.757221698760986, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 5.010960578918457, 'train_accuracy': 0.015625, 'train_precision': 0.002898550724637681, 'train_recall': 0.007246376811594203, 'train_f1': 0.004140786749482402}
# {'train_loss': 4.920504093170166, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 5.027009963989258, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.966737270355225, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.942027568817139, 'train_accuracy': 0.015625, 'train_precision': 0.014084507042253521, 'train_recall': 0.014084507042253521, 'train_f1': 0.014084507042253521}
# {'train_loss': 5.042024612426758, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.872457027435303, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.919078350067139, 'train_accuracy': 0.015625, 'train_precision': 0.013888888888888888, 'train_recall': 0.004629629629629629, 'train_f1': 0.006944444444444444}
# {'train_loss': 4.878759384155273, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.9250593185424805, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.964791297912598, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.866810321807861, 'train_accuracy': 0.046875, 'train_precision': 0.03205128205128205, 'train_recall': 0.038461538461538464, 'train_f1': 0.034188034188034185}
# {'train_loss': 4.942535400390625, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.894453525543213, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.855767250061035, 'train_accuracy': 0.015625, 'train_precision': 0.006944444444444444, 'train_recall': 0.006944444444444444, 'train_f1': 0.006944444444444444}
# {'train_loss': 5.037621974945068, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.840864658355713, 'train_accuracy': 0.015625, 'train_precision': 0.0035714285714285713, 'train_recall': 0.014285714285714285, 'train_f1': 0.005714285714285714}
# {'train_loss': 4.994875431060791, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.851972579956055, 'train_accuracy': 0.015625, 'train_precision': 0.013333333333333334, 'train_recall': 0.006666666666666667, 'train_f1': 0.008888888888888889}
# {'train_loss': 4.98737907409668, 'train_accuracy': 0.015625, 'train_precision': 0.012987012987012988, 'train_recall': 0.006493506493506494, 'train_f1': 0.008658008658008658}
# {'train_loss': 4.941992282867432, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.931324005126953, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 5.003857612609863, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 5.03055477142334, 'train_accuracy': 0.015625, 'train_precision': 0.014492753623188406, 'train_recall': 0.014492753623188406, 'train_f1': 0.014492753623188406}
# {'train_loss': 4.909541606903076, 'train_accuracy': 0.015625, 'train_precision': 0.003289473684210526, 'train_recall': 0.006578947368421052, 'train_f1': 0.0043859649122807015}
# {'train_loss': 4.974220275878906, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.963620662689209, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.864455223083496, 'train_accuracy': 0.046875, 'train_precision': 0.02531645569620253, 'train_recall': 0.0379746835443038, 'train_f1': 0.02953586497890295}
# {'train_loss': 4.9348931312561035, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.935222625732422, 'train_accuracy': 0.015625, 'train_precision': 0.008064516129032258, 'train_recall': 0.016129032258064516, 'train_f1': 0.01075268817204301}
# {'train_loss': 4.98016357421875, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.923853874206543, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.9006171226501465, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.891134738922119, 'train_accuracy': 0.046875, 'train_precision': 0.02666666666666667, 'train_recall': 0.02, 'train_f1': 0.02222222222222222}
# {'train_loss': 4.931853294372559, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.935137748718262, 'train_accuracy': 0.015625, 'train_precision': 0.006756756756756757, 'train_recall': 0.006756756756756757, 'train_f1': 0.006756756756756757}
# {'train_loss': 4.825000762939453, 'train_accuracy': 0.015625, 'train_precision': 0.013333333333333334, 'train_recall': 0.006666666666666667, 'train_f1': 0.008888888888888889}
# {'train_loss': 4.825166702270508, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.819314956665039, 'train_accuracy': 0.03125, 'train_precision': 0.010416666666666666, 'train_recall': 0.020833333333333332, 'train_f1': 0.013888888888888888}
# {'train_loss': 4.982321739196777, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.937241077423096, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.937099933624268, 'train_accuracy': 0.015625, 'train_precision': 0.0033783783783783786, 'train_recall': 0.013513513513513514, 'train_f1': 0.005405405405405406}
# {'train_loss': 4.880457878112793, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.951242446899414, 'train_accuracy': 0.015625, 'train_precision': 0.0045045045045045045, 'train_recall': 0.013513513513513514, 'train_f1': 0.006756756756756757}
# {'train_loss': 4.911025047302246, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.898806095123291, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.9436540603637695, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.928986072540283, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.881409168243408, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.9023895263671875, 'train_accuracy': 0.03125, 'train_precision': 0.0182648401826484, 'train_recall': 0.02054794520547945, 'train_f1': 0.01598173515981735}
# {'train_loss': 4.8734450340271, 'train_accuracy': 0.015625, 'train_precision': 0.006666666666666667, 'train_recall': 0.013333333333333334, 'train_f1': 0.008888888888888889}
# {'train_loss': 4.9428534507751465, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.931896686553955, 'train_accuracy': 0.015625, 'train_precision': 0.00684931506849315, 'train_recall': 0.0136986301369863, 'train_f1': 0.0091324200913242}
# {'train_loss': 4.8876471519470215, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 5.02516508102417, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.881591320037842, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.919185638427734, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.929446220397949, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.855632781982422, 'train_accuracy': 0.015625, 'train_precision': 0.0020703933747412005, 'train_recall': 0.007246376811594203, 'train_f1': 0.0032206119162640906}
# {'train_loss': 4.934030532836914, 'train_accuracy': 0.03125, 'train_precision': 0.014814814814814814, 'train_recall': 0.024691358024691357, 'train_f1': 0.01646090534979424}
# {'train_loss': 4.826606750488281, 'train_accuracy': 0.015625, 'train_precision': 0.006493506493506494, 'train_recall': 0.012987012987012988, 'train_f1': 0.008658008658008658}
# {'train_loss': 4.8366827964782715, 'train_accuracy': 0.03125, 'train_precision': 0.013888888888888888, 'train_recall': 0.013888888888888888, 'train_f1': 0.013888888888888888}
# {'train_loss': 4.908696174621582, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.979443550109863, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.873490810394287, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.865970134735107, 'train_accuracy': 0.015625, 'train_precision': 0.0136986301369863, 'train_recall': 0.0136986301369863, 'train_f1': 0.0136986301369863}
# {'train_loss': 4.906293869018555, 'train_accuracy': 0.046875, 'train_precision': 0.03333333333333333, 'train_recall': 0.03333333333333333, 'train_f1': 0.031111111111111107}
# {'train_loss': 4.911599159240723, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.772269248962402, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.8402276039123535, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.849914073944092, 'train_accuracy': 0.015625, 'train_precision': 0.006493506493506494, 'train_recall': 0.004329004329004329, 'train_f1': 0.005194805194805195}
# {'train_loss': 4.818861961364746, 'train_accuracy': 0.015625, 'train_precision': 0.012658227848101266, 'train_recall': 0.012658227848101266, 'train_f1': 0.012658227848101266}
# {'train_loss': 4.8226799964904785, 'train_accuracy': 0.015625, 'train_precision': 0.006944444444444444, 'train_recall': 0.006944444444444444, 'train_f1': 0.006944444444444444}
# {'train_loss': 4.864642143249512, 'train_accuracy': 0.015625, 'train_precision': 0.012987012987012988, 'train_recall': 0.006493506493506494, 'train_f1': 0.008658008658008658}
# {'train_loss': 4.906650066375732, 'train_accuracy': 0.015625, 'train_precision': 0.006329113924050633, 'train_recall': 0.006329113924050633, 'train_f1': 0.006329113924050633}
# {'train_loss': 4.959990978240967, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.86256742477417, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.909115314483643, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.8670196533203125, 'train_accuracy': 0.015625, 'train_precision': 0.013333333333333334, 'train_recall': 0.006666666666666667, 'train_f1': 0.008888888888888889}
# {'train_loss': 4.845163822174072, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.968236446380615, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.888306617736816, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.8583292961120605, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.954370975494385, 'train_accuracy': 0.015625, 'train_precision': 0.007042253521126761, 'train_recall': 0.007042253521126761, 'train_f1': 0.007042253521126761}
# {'train_loss': 4.821554183959961, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.901784896850586, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.947539806365967, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.904961109161377, 'train_accuracy': 0.015625, 'train_precision': 0.0045662100456621, 'train_recall': 0.0136986301369863, 'train_f1': 0.00684931506849315}
# {'train_loss': 4.832762241363525, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.860106468200684, 'train_accuracy': 0.015625, 'train_precision': 0.013513513513513514, 'train_recall': 0.0045045045045045045, 'train_f1': 0.006756756756756757}
# {'train_loss': 4.90324592590332, 'train_accuracy': 0.015625, 'train_precision': 0.013513513513513514, 'train_recall': 0.013513513513513514, 'train_f1': 0.013513513513513514}
# {'train_loss': 4.867804527282715, 'train_accuracy': 0.015625, 'train_precision': 0.013888888888888888, 'train_recall': 0.006944444444444444, 'train_f1': 0.009259259259259259}
# {'train_loss': 4.898236274719238, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.826293468475342, 'train_accuracy': 0.015625, 'train_precision': 0.004694835680751174, 'train_recall': 0.007042253521126761, 'train_f1': 0.005633802816901409}
# {'train_loss': 4.919389724731445, 'train_accuracy': 0.015625, 'train_precision': 0.014084507042253521, 'train_recall': 0.007042253521126761, 'train_f1': 0.009389671361502348}
# {'train_loss': 4.804312229156494, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.716278553009033, 'train_accuracy': 0.015625, 'train_precision': 0.007352941176470588, 'train_recall': 0.007352941176470588, 'train_f1': 0.007352941176470588}
# {'train_loss': 4.779172897338867, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.7555251121521, 'train_accuracy': 0.03125, 'train_precision': 0.011737089201877934, 'train_recall': 0.028169014084507043, 'train_f1': 0.016431924882629106}
# {'train_loss': 4.917126178741455, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.898612022399902, 'train_accuracy': 0.015625, 'train_precision': 0.006944444444444444, 'train_recall': 0.013888888888888888, 'train_f1': 0.009259259259259259}
# {'train_loss': 4.848233699798584, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.851197719573975, 'train_accuracy': 0.015625, 'train_precision': 0.006493506493506494, 'train_recall': 0.012987012987012988, 'train_f1': 0.008658008658008658}
# {'train_loss': 4.816379070281982, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.857419013977051, 'train_accuracy': 0.015625, 'train_precision': 0.014705882352941176, 'train_recall': 0.014705882352941176, 'train_f1': 0.014705882352941176}
# {'train_loss': 4.836156368255615, 'train_accuracy': 0.015625, 'train_precision': 0.006944444444444444, 'train_recall': 0.006944444444444444, 'train_f1': 0.006944444444444444}
# {'train_loss': 4.830901622772217, 'train_accuracy': 0.015625, 'train_precision': 0.014084507042253521, 'train_recall': 0.014084507042253521, 'train_f1': 0.014084507042253521}
# {'train_loss': 4.842097759246826, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.811874866485596, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.875749588012695, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.8160481452941895, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.763688564300537, 'train_accuracy': 0.015625, 'train_precision': 0.006493506493506494, 'train_recall': 0.012987012987012988, 'train_f1': 0.008658008658008658}
# {'train_loss': 4.749195098876953, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.897913932800293, 'train_accuracy': 0.015625, 'train_precision': 0.0044444444444444444, 'train_recall': 0.013333333333333334, 'train_f1': 0.006666666666666667}
# {'train_loss': 4.81387186050415, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.737301826477051, 'train_accuracy': 0.015625, 'train_precision': 0.006756756756756757, 'train_recall': 0.013513513513513514, 'train_f1': 0.009009009009009009}
# {'train_loss': 4.947957992553711, 'train_accuracy': 0.015625, 'train_precision': 0.012658227848101266, 'train_recall': 0.012658227848101266, 'train_f1': 0.012658227848101266}
# {'train_loss': 4.676830768585205, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.829164505004883, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.773550987243652, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.816765308380127, 'train_accuracy': 0.015625, 'train_precision': 0.007042253521126761, 'train_recall': 0.014084507042253521, 'train_f1': 0.009389671361502348}
# {'train_loss': 4.840818405151367, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.8406267166137695, 'train_accuracy': 0.03125, 'train_precision': 0.013513513513513514, 'train_recall': 0.02702702702702703, 'train_f1': 0.018018018018018018}
# {'train_loss': 4.857501029968262, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.822721004486084, 'train_accuracy': 0.015625, 'train_precision': 0.004629629629629629, 'train_recall': 0.006944444444444444, 'train_f1': 0.005555555555555556}
# {'train_loss': 4.775444984436035, 'train_accuracy': 0.015625, 'train_precision': 0.003472222222222222, 'train_recall': 0.006944444444444444, 'train_f1': 0.004629629629629629}
# {'train_loss': 4.686270236968994, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.699275970458984, 'train_accuracy': 0.03125, 'train_precision': 0.012658227848101266, 'train_recall': 0.012658227848101266, 'train_f1': 0.012658227848101266}
# {'train_loss': 4.6937456130981445, 'train_accuracy': 0.015625, 'train_precision': 0.013888888888888888, 'train_recall': 0.002777777777777778, 'train_f1': 0.00462962962962963}
# {'train_loss': 4.817000865936279, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.832544326782227, 'train_accuracy': 0.046875, 'train_precision': 0.014084507042253521, 'train_recall': 0.04225352112676056, 'train_f1': 0.02112676056338028}
# {'train_loss': 4.744070053100586, 'train_accuracy': 0.046875, 'train_precision': 0.017094017094017092, 'train_recall': 0.03205128205128205, 'train_f1': 0.021367521367521364}
# {'train_loss': 4.893845081329346, 'train_accuracy': 0.015625, 'train_precision': 0.014084507042253521, 'train_recall': 0.004694835680751174, 'train_f1': 0.007042253521126761}
# {'train_loss': 4.801490306854248, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.703650951385498, 'train_accuracy': 0.015625, 'train_precision': 0.01282051282051282, 'train_recall': 0.01282051282051282, 'train_f1': 0.01282051282051282}
# {'train_loss': 4.86994743347168, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.819544792175293, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.772550582885742, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.6802659034729, 'train_accuracy': 0.03125, 'train_precision': 0.02702702702702703, 'train_recall': 0.018018018018018018, 'train_f1': 0.02027027027027027}
# {'train_loss': 4.768833160400391, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.84298849105835, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.733800888061523, 'train_accuracy': 0.015625, 'train_precision': 0.0027397260273972603, 'train_recall': 0.003424657534246575, 'train_f1': 0.0030441400304414006}
# {'train_loss': 4.819386005401611, 'train_accuracy': 0.03125, 'train_precision': 0.018518518518518517, 'train_recall': 0.020833333333333332, 'train_f1': 0.016203703703703703}
# {'train_loss': 4.78083610534668, 'train_accuracy': 0.03125, 'train_precision': 0.02112676056338028, 'train_recall': 0.028169014084507043, 'train_f1': 0.023474178403755867}
# {'train_loss': 4.6233296394348145, 'train_accuracy': 0.015625, 'train_precision': 0.00684931506849315, 'train_recall': 0.0136986301369863, 'train_f1': 0.0091324200913242}
# {'train_loss': 4.706413745880127, 'train_accuracy': 0.015625, 'train_precision': 0.013513513513513514, 'train_recall': 0.006756756756756757, 'train_f1': 0.009009009009009009}
# {'train_loss': 4.72142219543457, 'train_accuracy': 0.03125, 'train_precision': 0.008771929824561403, 'train_recall': 0.019736842105263157, 'train_f1': 0.011842105263157895}
# {'train_loss': 4.703397274017334, 'train_accuracy': 0.0625, 'train_precision': 0.038288288288288286, 'train_recall': 0.0472972972972973, 'train_f1': 0.038288288288288286}
# {'train_loss': 4.760442733764648, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.803589344024658, 'train_accuracy': 0.015625, 'train_precision': 0.012048192771084338, 'train_recall': 0.012048192771084338, 'train_f1': 0.012048192771084338}
# {'train_loss': 4.837950229644775, 'train_accuracy': 0.03125, 'train_precision': 0.01875, 'train_recall': 0.01875, 'train_f1': 0.016666666666666666}
# {'train_loss': 4.709907531738281, 'train_accuracy': 0.015625, 'train_precision': 0.00641025641025641, 'train_recall': 0.004273504273504273, 'train_f1': 0.005128205128205128}
# {'train_loss': 4.800893306732178, 'train_accuracy': 0.03125, 'train_precision': 0.0091324200913242, 'train_recall': 0.0273972602739726, 'train_f1': 0.0136986301369863}
# {'train_loss': 4.73676872253418, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.620718002319336, 'train_accuracy': 0.0625, 'train_precision': 0.034375, 'train_recall': 0.04375, 'train_f1': 0.0375}
# {'train_loss': 4.72513484954834, 'train_accuracy': 0.015625, 'train_precision': 0.013888888888888888, 'train_recall': 0.013888888888888888, 'train_f1': 0.013888888888888888}
# {'train_loss': 4.714371681213379, 'train_accuracy': 0.015625, 'train_precision': 0.006756756756756757, 'train_recall': 0.006756756756756757, 'train_f1': 0.006756756756756757}
# {'train_loss': 4.717720985412598, 'train_accuracy': 0.03125, 'train_precision': 0.017543859649122806, 'train_recall': 0.02631578947368421, 'train_f1': 0.019736842105263157}
# {'train_loss': 4.668354511260986, 'train_accuracy': 0.015625, 'train_precision': 0.00625, 'train_recall': 0.0125, 'train_f1': 0.008333333333333333}
# {'train_loss': 4.729659557342529, 'train_accuracy': 0.0625, 'train_precision': 0.0410958904109589, 'train_recall': 0.04566210045662101, 'train_f1': 0.03881278538812785}
# {'train_loss': 4.711909294128418, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.760260581970215, 'train_accuracy': 0.015625, 'train_precision': 0.006578947368421052, 'train_recall': 0.013157894736842105, 'train_f1': 0.008771929824561403}
# {'train_loss': 4.750922679901123, 'train_accuracy': 0.015625, 'train_precision': 0.0136986301369863, 'train_recall': 0.00684931506849315, 'train_f1': 0.0091324200913242}
# {'train_loss': 4.7186055183410645, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.810875415802002, 'train_accuracy': 0.015625, 'train_precision': 0.003125, 'train_recall': 0.00625, 'train_f1': 0.004166666666666667}
# {'train_loss': 4.6425652503967285, 'train_accuracy': 0.046875, 'train_precision': 0.03333333333333333, 'train_recall': 0.04, 'train_f1': 0.035555555555555556}
# {'train_loss': 4.730185031890869, 'train_accuracy': 0.015625, 'train_precision': 0.013513513513513514, 'train_recall': 0.006756756756756757, 'train_f1': 0.009009009009009009}
# {'train_loss': 4.813838005065918, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.824991226196289, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.770898818969727, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.783709526062012, 'train_accuracy': 0.046875, 'train_precision': 0.023809523809523808, 'train_recall': 0.032467532467532464, 'train_f1': 0.026839826839826837}
# {'train_loss': 4.756303310394287, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.809433937072754, 'train_accuracy': 0.015625, 'train_precision': 0.0136986301369863, 'train_recall': 0.0136986301369863, 'train_f1': 0.0136986301369863}
# {'train_loss': 4.789112567901611, 'train_accuracy': 0.015625, 'train_precision': 0.006493506493506494, 'train_recall': 0.012987012987012988, 'train_f1': 0.008658008658008658}
# {'train_loss': 4.76528263092041, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.736838340759277, 'train_accuracy': 0.015625, 'train_precision': 0.013513513513513514, 'train_recall': 0.013513513513513514, 'train_f1': 0.013513513513513514}
# {'train_loss': 4.649606704711914, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.711143970489502, 'train_accuracy': 0.015625, 'train_precision': 0.0022222222222222222, 'train_recall': 0.0044444444444444444, 'train_f1': 0.002962962962962963}
# {'train_loss': 4.679405212402344, 'train_accuracy': 0.03125, 'train_precision': 0.020833333333333332, 'train_recall': 0.027777777777777776, 'train_f1': 0.023148148148148147}
# {'train_loss': 4.667712211608887, 'train_accuracy': 0.03125, 'train_precision': 0.018518518518518517, 'train_recall': 0.027777777777777776, 'train_f1': 0.020833333333333332}
# {'train_loss': 4.701498508453369, 'train_accuracy': 0.015625, 'train_precision': 0.012987012987012988, 'train_recall': 0.006493506493506494, 'train_f1': 0.008658008658008658}
# {'train_loss': 4.721508979797363, 'train_accuracy': 0.015625, 'train_precision': 0.006756756756756757, 'train_recall': 0.006756756756756757, 'train_f1': 0.006756756756756757}
# {'train_loss': 4.6918625831604, 'train_accuracy': 0.015625, 'train_precision': 0.012987012987012988, 'train_recall': 0.006493506493506494, 'train_f1': 0.008658008658008658}
# {'train_loss': 4.624827861785889, 'train_accuracy': 0.015625, 'train_precision': 0.006578947368421052, 'train_recall': 0.013157894736842105, 'train_f1': 0.008771929824561403}
# {'train_loss': 4.7208662033081055, 'train_accuracy': 0.015625, 'train_precision': 0.013157894736842105, 'train_recall': 0.013157894736842105, 'train_f1': 0.013157894736842105}
# {'train_loss': 4.7630486488342285, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.75462007522583, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.7109055519104, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.652018070220947, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.662826061248779, 'train_accuracy': 0.015625, 'train_precision': 0.014285714285714285, 'train_recall': 0.0047619047619047615, 'train_f1': 0.007142857142857143}
# {'train_loss': 4.7423272132873535, 'train_accuracy': 0.015625, 'train_precision': 0.013333333333333334, 'train_recall': 0.006666666666666667, 'train_f1': 0.008888888888888889}
# {'train_loss': 4.7103400230407715, 'train_accuracy': 0.03125, 'train_precision': 0.02666666666666667, 'train_recall': 0.02666666666666667, 'train_f1': 0.02666666666666667}
# {'train_loss': 4.631180763244629, 'train_accuracy': 0.03125, 'train_precision': 0.014285714285714285, 'train_recall': 0.019047619047619046, 'train_f1': 0.015238095238095238}
# {'train_loss': 4.665139198303223, 'train_accuracy': 0.015625, 'train_precision': 0.005747126436781609, 'train_recall': 0.011494252873563218, 'train_f1': 0.007662835249042145}
# {'train_loss': 4.669864177703857, 'train_accuracy': 0.03125, 'train_precision': 0.025974025974025976, 'train_recall': 0.01948051948051948, 'train_f1': 0.021645021645021644}
# {'train_loss': 4.751729965209961, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.5542168617248535, 'train_accuracy': 0.046875, 'train_precision': 0.032467532467532464, 'train_recall': 0.025974025974025976, 'train_f1': 0.028138528138528136}
# {'train_loss': 4.558877944946289, 'train_accuracy': 0.046875, 'train_precision': 0.0375, 'train_recall': 0.03125, 'train_f1': 0.03333333333333333}
# {'train_loss': 4.629390716552734, 'train_accuracy': 0.015625, 'train_precision': 0.00228310502283105, 'train_recall': 0.0136986301369863, 'train_f1': 0.003913894324853229}
# {'train_loss': 4.66795539855957, 'train_accuracy': 0.046875, 'train_precision': 0.02511415525114155, 'train_recall': 0.0273972602739726, 'train_f1': 0.023744292237442923}
# {'train_loss': 4.597845077514648, 'train_accuracy': 0.0625, 'train_precision': 0.03571428571428571, 'train_recall': 0.03214285714285714, 'train_f1': 0.03095238095238095}
# {'train_loss': 4.596835136413574, 'train_accuracy': 0.03125, 'train_precision': 0.009259259259259259, 'train_recall': 0.027777777777777776, 'train_f1': 0.013888888888888888}
# {'train_loss': 4.646899223327637, 'train_accuracy': 0.015625, 'train_precision': 0.013157894736842105, 'train_recall': 0.006578947368421052, 'train_f1': 0.008771929824561403}
# {'train_loss': 4.681943416595459, 'train_accuracy': 0.015625, 'train_precision': 0.013157894736842105, 'train_recall': 0.0043859649122807015, 'train_f1': 0.006578947368421052}
# {'train_loss': 4.6258344650268555, 'train_accuracy': 0.015625, 'train_precision': 0.0043859649122807015, 'train_recall': 0.013157894736842105, 'train_f1': 0.006578947368421052}
# {'train_loss': 4.574825763702393, 'train_accuracy': 0.046875, 'train_precision': 0.04285714285714286, 'train_recall': 0.03571428571428571, 'train_f1': 0.03809523809523809}
# {'train_loss': 4.524388790130615, 'train_accuracy': 0.0625, 'train_precision': 0.04, 'train_recall': 0.04444444444444444, 'train_f1': 0.040888888888888884}
# {'train_loss': 4.622851371765137, 'train_accuracy': 0.015625, 'train_precision': 0.006666666666666667, 'train_recall': 0.013333333333333334, 'train_f1': 0.008888888888888889}
# {'train_loss': 4.619642734527588, 'train_accuracy': 0.0625, 'train_precision': 0.029914529914529916, 'train_recall': 0.03632478632478632, 'train_f1': 0.028632478632478635}
# {'train_loss': 4.608893871307373, 'train_accuracy': 0.015625, 'train_precision': 0.0136986301369863, 'train_recall': 0.003424657534246575, 'train_f1': 0.005479452054794521}
# {'train_loss': 4.591948986053467, 'train_accuracy': 0.046875, 'train_precision': 0.023809523809523808, 'train_recall': 0.03896103896103896, 'train_f1': 0.028138528138528136}
# {'train_loss': 4.582550048828125, 'train_accuracy': 0.078125, 'train_precision': 0.051470588235294115, 'train_recall': 0.04044117647058824, 'train_f1': 0.041666666666666664}
# {'train_loss': 4.656399250030518, 'train_accuracy': 0.0, 'train_precision': 0.0, 'train_recall': 0.0, 'train_f1': 0.0}
# {'train_loss': 4.679592609405518, 'train_accuracy': 0.046875, 'train_precision': 0.017123287671232876, 'train_recall': 0.0273972602739726, 'train_f1': 0.01917808219178082}
# {'train_loss': 4.533141136169434, 'train_accuracy': 0.109375, 'train_precision': 0.06904761904761904, 'train_recall': 0.08571428571428572, 'train_f1': 0.07265306122448979}
# {'train_loss': 4.68658447265625, 'train_accuracy': 0.015625, 'train_precision': 0.013888888888888888, 'train_recall': 0.006944444444444444, 'train_f1': 0.009259259259259259}
# {'train_loss': 4.619197368621826, 'train_accuracy': 0.015625, 'train_precision': 0.007142857142857143, 'train_recall': 0.014285714285714285, 'train_f1': 0.009523809523809523}
# {'train_loss': 4.560554027557373, 'train_accuracy': 0.09375, 'train_precision': 0.041666666666666664, 'train_recall': 0.07236842105263158, 'train_f1': 0.04824561403508772}
# {'train_loss': 4.565146446228027, 'train_accuracy': 0.078125, 'train_precision': 0.05526315789473685, 'train_recall': 0.05263157894736842, 'train_f1': 0.04824561403508772}
# {'train_loss': 4.5749192237854, 'train_accuracy': 0.03125, 'train_precision': 0.011904761904761904, 'train_recall': 0.017142857142857144, 'train_f1': 0.013095238095238096}
# {'train_loss': 4.604056358337402, 'train_accuracy': 0.0625, 'train_precision': 0.02968036529680365, 'train_recall': 0.02968036529680365, 'train_f1': 0.02968036529680365}
# {'train_loss': 4.681968688964844, 'train_accuracy': 0.015625, 'train_precision': 0.014084507042253521, 'train_recall': 0.007042253521126761, 'train_f1': 0.009389671361502348}
# {'train_loss': 4.533370018005371, 'train_accuracy': 0.03125, 'train_precision': 0.020833333333333332, 'train_recall': 0.027777777777777776, 'train_f1': 0.023148148148148147}
# {'train_loss': 4.514970779418945, 'train_accuracy': 0.109375, 'train_precision': 0.07462686567164178, 'train_recall': 0.07462686567164178, 'train_f1': 0.06915422885572138}
# {'train_loss': 4.485637187957764, 'train_accuracy': 0.125, 'train_precision': 0.06896551724137931, 'train_recall': 0.05172413793103448, 'train_f1': 0.057471264367816084}
# Test
# {'test_loss': 4.515403747558594, 'test_accuracy': 0.0, 'test_precision': 0.0, 'test_recall': 0.0, 'test_f1': 0.0}
# {'test_loss': 4.439164638519287, 'test_accuracy': 0.0625, 'test_precision': 0.024122807017543862, 'test_recall': 0.03289473684210526, 'test_f1': 0.026973684210526313}
# {'test_loss': 4.379557132720947, 'test_accuracy': 0.0625, 'test_precision': 0.04776119402985075, 'test_recall': 0.05223880597014925, 'test_f1': 0.04904051172707889}
# {'test_loss': 4.450985908508301, 'test_accuracy': 0.125, 'test_precision': 0.06904761904761904, 'test_recall': 0.08571428571428572, 'test_f1': 0.0738095238095238}
# {'test_loss': 4.605075359344482, 'test_accuracy': 0.03125, 'test_precision': 0.017777777777777778, 'test_recall': 0.02666666666666667, 'test_f1': 0.02}
# {'test_loss': 4.540700912475586, 'test_accuracy': 0.03125, 'test_precision': 0.0189873417721519, 'test_recall': 0.016877637130801686, 'test_f1': 0.014767932489451475}
# {'test_loss': 4.519755840301514, 'test_accuracy': 0.046875, 'test_precision': 0.021689497716894976, 'test_recall': 0.0410958904109589, 'test_f1': 0.02602739726027397}
# {'test_loss': 4.465822696685791, 'test_accuracy': 0.0625, 'test_precision': 0.05303030303030303, 'test_recall': 0.06060606060606061, 'test_f1': 0.05555555555555555}
# {'test_loss': 4.475144386291504, 'test_accuracy': 0.0625, 'test_precision': 0.02054794520547945, 'test_recall': 0.0410958904109589, 'test_f1': 0.0273972602739726}
# {'test_loss': 4.564873695373535, 'test_accuracy': 0.0625, 'test_precision': 0.03873239436619718, 'test_recall': 0.04225352112676056, 'test_f1': 0.03380281690140845}
# {'test_loss': 4.610239505767822, 'test_accuracy': 0.0, 'test_precision': 0.0, 'test_recall': 0.0, 'test_f1': 0.0}
# {'test_loss': 4.578742980957031, 'test_accuracy': 0.03125, 'test_precision': 0.016666666666666666, 'test_recall': 0.02, 'test_f1': 0.017777777777777778}
# {'test_loss': 4.579123497009277, 'test_accuracy': 0.015625, 'test_precision': 0.007142857142857143, 'test_recall': 0.014285714285714285, 'test_f1': 0.009523809523809523}
# {'test_loss': 4.497798919677734, 'test_accuracy': 0.015625, 'test_precision': 0.002777777777777778, 'test_recall': 0.013888888888888888, 'test_f1': 0.00462962962962963}
# {'test_loss': 4.563685894012451, 'test_accuracy': 0.0625, 'test_precision': 0.030821917808219176, 'test_recall': 0.04794520547945205, 'test_f1': 0.0365296803652968}
# {'test_loss': 4.545679092407227, 'test_accuracy': 0.078125, 'test_precision': 0.04666666666666667, 'test_recall': 0.06666666666666667, 'test_f1': 0.050666666666666665}
# {'test_loss': 4.546994209289551, 'test_accuracy': 0.015625, 'test_precision': 0.01282051282051282, 'test_recall': 0.004273504273504273, 'test_f1': 0.00641025641025641}
# {'test_loss': 4.438745021820068, 'test_accuracy': 0.078125, 'test_precision': 0.04975124378109452, 'test_recall': 0.05472636815920398, 'test_f1': 0.04925373134328358}
# {'test_loss': 4.509994029998779, 'test_accuracy': 0.03125, 'test_precision': 0.017543859649122806, 'test_recall': 0.02631578947368421, 'test_f1': 0.019736842105263157}
# {'test_loss': 4.571331024169922, 'test_accuracy': 0.046875, 'test_precision': 0.036231884057971016, 'test_recall': 0.036231884057971016, 'test_f1': 0.033816425120772944}
# {'test_loss': 4.560611724853516, 'test_accuracy': 0.0625, 'test_precision': 0.04430379746835443, 'test_recall': 0.04430379746835443, 'test_f1': 0.04430379746835443}
# {'test_loss': 4.579379558563232, 'test_accuracy': 0.03125, 'test_precision': 0.02027027027027027, 'test_recall': 0.02702702702702703, 'test_f1': 0.02252252252252252}
# {'test_loss': 4.559457778930664, 'test_accuracy': 0.03125, 'test_precision': 0.012987012987012988, 'test_recall': 0.025974025974025976, 'test_f1': 0.017316017316017316}
# {'test_loss': 4.5332231521606445, 'test_accuracy': 0.046875, 'test_precision': 0.02112676056338028, 'test_recall': 0.028169014084507043, 'test_f1': 0.023474178403755867}
# {'test_loss': 4.531160354614258, 'test_accuracy': 0.0, 'test_precision': 0.0, 'test_recall': 0.0, 'test_f1': 0.0}
# {'test_loss': 4.4797539710998535, 'test_accuracy': 0.078125, 'test_precision': 0.03125, 'test_recall': 0.046296296296296294, 'test_f1': 0.03425925925925926}
# {'test_loss': 4.421597480773926, 'test_accuracy': 0.0625, 'test_precision': 0.051470588235294115, 'test_recall': 0.04044117647058824, 'test_f1': 0.044117647058823525}
# {'test_loss': 4.503781318664551, 'test_accuracy': 0.0625, 'test_precision': 0.04, 'test_recall': 0.04666666666666667, 'test_f1': 0.04}
# {'test_loss': 4.53700590133667, 'test_accuracy': 0.0625, 'test_precision': 0.03632478632478633, 'test_recall': 0.04487179487179487, 'test_f1': 0.03632478632478632}
# {'test_loss': 4.520653247833252, 'test_accuracy': 0.03125, 'test_precision': 0.017777777777777778, 'test_recall': 0.013333333333333334, 'test_f1': 0.014222222222222221}
# {'test_loss': 4.463826656341553, 'test_accuracy': 0.09375, 'test_precision': 0.046825396825396826, 'test_recall': 0.046296296296296294, 'test_f1': 0.0436885865457294}
# {'test_loss': 4.494422435760498, 'test_accuracy': 0.046875, 'test_precision': 0.038461538461538464, 'test_recall': 0.023504273504273504, 'test_f1': 0.027777777777777776}
# {'test_loss': 4.51764440536499, 'test_accuracy': 0.046875, 'test_precision': 0.02462121212121212, 'test_recall': 0.03787878787878788, 'test_f1': 0.02828282828282828}
# {'test_loss': 4.515230655670166, 'test_accuracy': 0.03125, 'test_precision': 0.013888888888888888, 'test_recall': 0.013888888888888888, 'test_f1': 0.013888888888888888}
# {'test_loss': 4.425699234008789, 'test_accuracy': 0.015625, 'test_precision': 0.00684931506849315, 'test_recall': 0.0136986301369863, 'test_f1': 0.0091324200913242}
# {'test_loss': 4.522946357727051, 'test_accuracy': 0.0625, 'test_precision': 0.024305555555555556, 'test_recall': 0.04861111111111111, 'test_f1': 0.02986111111111111}
# {'test_loss': 4.504297256469727, 'test_accuracy': 0.0625, 'test_precision': 0.029047619047619044, 'test_recall': 0.05714285714285714, 'test_f1': 0.03571428571428571}
# {'test_loss': 4.494809150695801, 'test_accuracy': 0.046875, 'test_precision': 0.031111111111111107, 'test_recall': 0.021111111111111112, 'test_f1': 0.02380952380952381}
# {'test_loss': 4.461450576782227, 'test_accuracy': 0.03125, 'test_precision': 0.010256410256410256, 'test_recall': 0.015384615384615385, 'test_f1': 0.012307692307692308}
# {'test_loss': 4.53727388381958, 'test_accuracy': 0.0625, 'test_precision': 0.03333333333333333, 'test_recall': 0.05333333333333334, 'test_f1': 0.04}
# {'test_loss': 4.453972339630127, 'test_accuracy': 0.0625, 'test_precision': 0.013457556935817806, 'test_recall': 0.028985507246376812, 'test_f1': 0.018357487922705314}
# {'test_loss': 4.5370917320251465, 'test_accuracy': 0.03125, 'test_precision': 0.013888888888888888, 'test_recall': 0.027777777777777776, 'test_f1': 0.018518518518518517}
# {'test_loss': 4.591280460357666, 'test_accuracy': 0.046875, 'test_precision': 0.019594594594594596, 'test_recall': 0.03153153153153153, 'test_f1': 0.022297297297297295}
# {'test_loss': 4.558676719665527, 'test_accuracy': 0.046875, 'test_precision': 0.019718309859154928, 'test_recall': 0.023474178403755867, 'test_f1': 0.02112676056338028}
# {'test_loss': 4.515356540679932, 'test_accuracy': 0.078125, 'test_precision': 0.02968036529680365, 'test_recall': 0.0547945205479452, 'test_f1': 0.0365296803652968}
# {'test_loss': 4.559087753295898, 'test_accuracy': 0.046875, 'test_precision': 0.03571428571428571, 'test_recall': 0.02857142857142857, 'test_f1': 0.03095238095238095}
# {'test_loss': 4.477908611297607, 'test_accuracy': 0.015625, 'test_precision': 0.00228310502283105, 'test_recall': 0.0136986301369863, 'test_f1': 0.003913894324853229}
# {'test_loss': 4.436907768249512, 'test_accuracy': 0.109375, 'test_precision': 0.05454545454545455, 'test_recall': 0.07142857142857142, 'test_f1': 0.05627705627705627}
# {'test_loss': 4.593369007110596, 'test_accuracy': 0.046875, 'test_precision': 0.026960784313725488, 'test_recall': 0.03431372549019608, 'test_f1': 0.024509803921568624}
# {'test_loss': 4.443312644958496, 'test_accuracy': 0.046875, 'test_precision': 0.034313725490196074, 'test_recall': 0.03676470588235294, 'test_f1': 0.03529411764705882}
# {'test_loss': 4.618524551391602, 'test_accuracy': 0.0625, 'test_precision': 0.05, 'test_recall': 0.04285714285714286, 'test_f1': 0.04285714285714285}
# {'test_loss': 4.580270767211914, 'test_accuracy': 0.015625, 'test_precision': 0.004694835680751174, 'test_recall': 0.007042253521126761, 'test_f1': 0.005633802816901409}
# {'test_loss': 4.444564342498779, 'test_accuracy': 0.03125, 'test_precision': 0.02666666666666667, 'test_recall': 0.017777777777777778, 'test_f1': 0.02}
# {'test_loss': 4.57566499710083, 'test_accuracy': 0.0625, 'test_precision': 0.0410958904109589, 'test_recall': 0.0410958904109589, 'test_f1': 0.0410958904109589}
# {'test_loss': 4.554365158081055, 'test_accuracy': 0.015625, 'test_precision': 0.014084507042253521, 'test_recall': 0.007042253521126761, 'test_f1': 0.009389671361502348}
# {'test_loss': 4.546642303466797, 'test_accuracy': 0.046875, 'test_precision': 0.03535353535353535, 'test_recall': 0.045454545454545456, 'test_f1': 0.03787878787878788}
# ...
# {'train_loss': 0.9273711442947388, 'train_accuracy': 0.78125, 'train_precision': 0.6478494623655914, 'train_recall': 0.6559139784946236, 'train_f1': 0.6478494623655914}
# {'train_loss': 1.0447642803192139, 'train_accuracy': 0.703125, 'train_precision': 0.5871794871794871, 'train_recall': 0.5692307692307692, 'train_f1': 0.5712820512820512}
# {'train_loss': 0.7430396676063538, 'train_accuracy': 0.734375, 'train_precision': 0.6059322033898306, 'train_recall': 0.6169491525423728, 'train_f1': 0.5983857949959644}
# {'train_loss': 0.7276421189308167, 'train_accuracy': 0.828125, 'train_precision': 0.7142857142857143, 'train_recall': 0.7232142857142857, 'train_f1': 0.7113095238095237}
# {'train_loss': 0.9243724942207336, 'train_accuracy': 0.75, 'train_precision': 0.6491228070175439, 'train_recall': 0.6052631578947368, 'train_f1': 0.6140350877192983}
# {'train_loss': 1.0152863264083862, 'train_accuracy': 0.75, 'train_precision': 0.5819672131147541, 'train_recall': 0.5819672131147541, 'train_f1': 0.5792349726775956}
# {'train_loss': 0.8216571807861328, 'train_accuracy': 0.796875, 'train_precision': 0.6810344827586207, 'train_recall': 0.7068965517241379, 'train_f1': 0.6839080459770115}
# {'train_loss': 0.7063747048377991, 'train_accuracy': 0.796875, 'train_precision': 0.7191358024691359, 'train_recall': 0.7037037037037037, 'train_f1': 0.7006172839506173}
# {'train_loss': 0.9938708543777466, 'train_accuracy': 0.703125, 'train_precision': 0.521164021164021, 'train_recall': 0.5317460317460317, 'train_f1': 0.5201058201058201}
# {'train_loss': 0.7143648266792297, 'train_accuracy': 0.78125, 'train_precision': 0.681761006289308, 'train_recall': 0.6572327044025157, 'train_f1': 0.6551362683438156}
# {'train_loss': 1.1141610145568848, 'train_accuracy': 0.75, 'train_precision': 0.6091954022988505, 'train_recall': 0.6264367816091954, 'train_f1': 0.610919540229885}
# {'train_loss': 0.681033194065094, 'train_accuracy': 0.828125, 'train_precision': 0.7339181286549707, 'train_recall': 0.75, 'train_f1': 0.7331662489557227}
# {'train_loss': 0.7347455024719238, 'train_accuracy': 0.765625, 'train_precision': 0.6695402298850575, 'train_recall': 0.6436781609195401, 'train_f1': 0.6448275862068965}
# {'train_loss': 1.1112010478973389, 'train_accuracy': 0.71875, 'train_precision': 0.5502645502645502, 'train_recall': 0.5476190476190477, 'train_f1': 0.5417989417989418}
# {'train_loss': 0.6461570262908936, 'train_accuracy': 0.828125, 'train_precision': 0.6724137931034483, 'train_recall': 0.6839080459770115, 'train_f1': 0.6747126436781609}
# {'train_loss': 1.0487080812454224, 'train_accuracy': 0.71875, 'train_precision': 0.5897435897435898, 'train_recall': 0.6089743589743589, 'train_f1': 0.5794871794871794}
# {'train_loss': 0.8731278777122498, 'train_accuracy': 0.75, 'train_precision': 0.6235632183908046, 'train_recall': 0.6379310344827587, 'train_f1': 0.6149425287356322}
# {'train_loss': 0.5818617343902588, 'train_accuracy': 0.890625, 'train_precision': 0.8055555555555556, 'train_recall': 0.8179012345679012, 'train_f1': 0.8049382716049381}
# {'train_loss': 0.6376633644104004, 'train_accuracy': 0.796875, 'train_precision': 0.675287356321839, 'train_recall': 0.675287356321839, 'train_f1': 0.671264367816092}
# {'train_loss': 0.7765134572982788, 'train_accuracy': 0.78125, 'train_precision': 0.7049180327868853, 'train_recall': 0.6857923497267758, 'train_f1': 0.6923497267759563}
# {'train_loss': 0.9072245359420776, 'train_accuracy': 0.703125, 'train_precision': 0.5402777777777777, 'train_recall': 0.5611111111111111, 'train_f1': 0.540952380952381}
# {'train_loss': 1.1454826593399048, 'train_accuracy': 0.71875, 'train_precision': 0.6120689655172413, 'train_recall': 0.6637931034482759, 'train_f1': 0.6235632183908045}
# {'train_loss': 0.9542797803878784, 'train_accuracy': 0.78125, 'train_precision': 0.674863387978142, 'train_recall': 0.6475409836065574, 'train_f1': 0.6524590163934426}
# {'train_loss': 0.9388173818588257, 'train_accuracy': 0.71875, 'train_precision': 0.5992647058823529, 'train_recall': 0.6102941176470589, 'train_f1': 0.59593837535014}
# {'train_loss': 0.5991224050521851, 'train_accuracy': 0.875, 'train_precision': 0.8364197530864198, 'train_recall': 0.8364197530864198, 'train_f1': 0.8302469135802469}
# {'train_loss': 0.7699903845787048, 'train_accuracy': 0.78125, 'train_precision': 0.6551724137931034, 'train_recall': 0.6666666666666666, 'train_f1': 0.6511494252873563}
# {'train_loss': 0.8516761660575867, 'train_accuracy': 0.8125, 'train_precision': 0.7163742690058479, 'train_recall': 0.7046783625730995, 'train_f1': 0.7070175438596492}
# {'train_loss': 0.650007426738739, 'train_accuracy': 0.828125, 'train_precision': 0.7023809523809523, 'train_recall': 0.7142857142857143, 'train_f1': 0.7011904761904761}
# {'train_loss': 0.45025351643562317, 'train_accuracy': 0.875, 'train_precision': 0.7403846153846154, 'train_recall': 0.7307692307692307, 'train_f1': 0.7307692307692307}
# {'train_loss': 0.9623804092407227, 'train_accuracy': 0.71875, 'train_precision': 0.6206896551724138, 'train_recall': 0.6091954022988505, 'train_f1': 0.5948275862068966}
# {'train_loss': 0.8431086540222168, 'train_accuracy': 0.8125, 'train_precision': 0.7242424242424241, 'train_recall': 0.7545454545454545, 'train_f1': 0.7290909090909091}
# {'train_loss': 1.1390796899795532, 'train_accuracy': 0.71875, 'train_precision': 0.6209677419354839, 'train_recall': 0.6451612903225806, 'train_f1': 0.6209677419354839}
# {'train_loss': 1.0680210590362549, 'train_accuracy': 0.6875, 'train_precision': 0.5760233918128654, 'train_recall': 0.5833333333333334, 'train_f1': 0.569423558897243}
# {'train_loss': 0.7620774507522583, 'train_accuracy': 0.75, 'train_precision': 0.6416666666666667, 'train_recall': 0.6833333333333333, 'train_f1': 0.6522222222222223}
# {'train_loss': 0.8375347256660461, 'train_accuracy': 0.71875, 'train_precision': 0.5887096774193549, 'train_recall': 0.6064516129032258, 'train_f1': 0.5873655913978494}
# {'train_loss': 0.880936324596405, 'train_accuracy': 0.75, 'train_precision': 0.6711309523809524, 'train_recall': 0.6726190476190476, 'train_f1': 0.6575680272108844}
# {'train_loss': 0.8793373107910156, 'train_accuracy': 0.78125, 'train_precision': 0.7138888888888888, 'train_recall': 0.7055555555555555, 'train_f1': 0.6972222222222223}
# {'train_loss': 0.7622961401939392, 'train_accuracy': 0.8125, 'train_precision': 0.7134502923976608, 'train_recall': 0.7046783625730993, 'train_f1': 0.7005847953216374}
# {'train_loss': 0.8898116946220398, 'train_accuracy': 0.796875, 'train_precision': 0.7021604938271605, 'train_recall': 0.7376543209876544, 'train_f1': 0.709700176366843}
# {'train_loss': 0.8563714623451233, 'train_accuracy': 0.734375, 'train_precision': 0.6092896174863388, 'train_recall': 0.6120218579234973, 'train_f1': 0.6005464480874317}
# {'train_loss': 0.7083564400672913, 'train_accuracy': 0.8125, 'train_precision': 0.7351190476190476, 'train_recall': 0.7291666666666666, 'train_f1': 0.7226190476190476}
# {'train_loss': 0.9597864747047424, 'train_accuracy': 0.8125, 'train_precision': 0.6547619047619048, 'train_recall': 0.6904761904761906, 'train_f1': 0.6654761904761904}
# {'train_loss': 0.913798987865448, 'train_accuracy': 0.75, 'train_precision': 0.625, 'train_recall': 0.6222222222222222, 'train_f1': 0.6138888888888888}
# {'train_loss': 1.0303367376327515, 'train_accuracy': 0.78125, 'train_precision': 0.6900584795321638, 'train_recall': 0.7017543859649122, 'train_f1': 0.6830409356725147}
# {'train_loss': 1.207285761833191, 'train_accuracy': 0.640625, 'train_precision': 0.5453216374269005, 'train_recall': 0.5526315789473685, 'train_f1': 0.5319966583124477}
# {'train_loss': 0.916384756565094, 'train_accuracy': 0.78125, 'train_precision': 0.6864406779661016, 'train_recall': 0.6892655367231639, 'train_f1': 0.6774011299435028}
# {'train_loss': 1.0775303840637207, 'train_accuracy': 0.71875, 'train_precision': 0.5848214285714286, 'train_recall': 0.5773809523809523, 'train_f1': 0.573639455782313}
# {'train_loss': 0.8711977601051331, 'train_accuracy': 0.75, 'train_precision': 0.6305555555555556, 'train_recall': 0.6583333333333333, 'train_f1': 0.63}
# {'train_loss': 0.7700099945068359, 'train_accuracy': 0.84375, 'train_precision': 0.7735849056603774, 'train_recall': 0.8113207547169812, 'train_f1': 0.7798742138364779}
# {'train_loss': 1.233681082725525, 'train_accuracy': 0.734375, 'train_precision': 0.6181818181818182, 'train_recall': 0.6181818181818182, 'train_f1': 0.6042424242424241}
# {'train_loss': 0.8714143633842468, 'train_accuracy': 0.765625, 'train_precision': 0.6666666666666666, 'train_recall': 0.6878787878787878, 'train_f1': 0.663030303030303}
# {'train_loss': 0.92671799659729, 'train_accuracy': 0.765625, 'train_precision': 0.6505376344086021, 'train_recall': 0.674731182795699, 'train_f1': 0.6505376344086021}
# {'train_loss': 0.9580686688423157, 'train_accuracy': 0.765625, 'train_precision': 0.6754385964912281, 'train_recall': 0.6301169590643274, 'train_f1': 0.646031746031746}
# {'train_loss': 0.6404685378074646, 'train_accuracy': 0.828125, 'train_precision': 0.7203389830508474, 'train_recall': 0.731638418079096, 'train_f1': 0.7225988700564973}
# {'train_loss': 1.05056893825531, 'train_accuracy': 0.71875, 'train_precision': 0.5819444444444444, 'train_recall': 0.575, 'train_f1': 0.5665079365079364}
# {'train_loss': 0.883247435092926, 'train_accuracy': 0.78125, 'train_precision': 0.6949152542372882, 'train_recall': 0.690677966101695, 'train_f1': 0.6847457627118644}
# {'train_loss': 0.8288223147392273, 'train_accuracy': 0.75, 'train_precision': 0.5524691358024691, 'train_recall': 0.5617283950617283, 'train_f1': 0.5462962962962963}
# {'train_loss': 0.9091815948486328, 'train_accuracy': 0.78125, 'train_precision': 0.6977401129943503, 'train_recall': 0.6457627118644068, 'train_f1': 0.6590395480225989}
# {'train_loss': 0.8577134609222412, 'train_accuracy': 0.71875, 'train_precision': 0.5706214689265536, 'train_recall': 0.576271186440678, 'train_f1': 0.5672316384180791}
# {'train_loss': 1.0206314325332642, 'train_accuracy': 0.734375, 'train_precision': 0.6823899371069182, 'train_recall': 0.7106918238993711, 'train_f1': 0.6685534591194968}
# {'train_loss': 0.8956105709075928, 'train_accuracy': 0.796875, 'train_precision': 0.6982758620689655, 'train_recall': 0.6896551724137931, 'train_f1': 0.6839080459770116}
# {'train_loss': 1.0858289003372192, 'train_accuracy': 0.703125, 'train_precision': 0.5792349726775956, 'train_recall': 0.592896174863388, 'train_f1': 0.5759562841530055}
# {'train_loss': 0.9547083377838135, 'train_accuracy': 0.765625, 'train_precision': 0.6681034482758621, 'train_recall': 0.6479885057471264, 'train_f1': 0.6422413793103449}
# {'train_loss': 0.8775341510772705, 'train_accuracy': 0.765625, 'train_precision': 0.6282051282051283, 'train_recall': 0.6185897435897435, 'train_f1': 0.6115384615384615}
# {'train_loss': 0.9767892956733704, 'train_accuracy': 0.734375, 'train_precision': 0.575268817204301, 'train_recall': 0.5967741935483871, 'train_f1': 0.5774193548387097}
# {'train_loss': 0.7672768831253052, 'train_accuracy': 0.8125, 'train_precision': 0.7083333333333333, 'train_recall': 0.7166666666666667, 'train_f1': 0.7088888888888889}
# {'train_loss': 0.9823958873748779, 'train_accuracy': 0.8125, 'train_precision': 0.7053571428571429, 'train_recall': 0.6994047619047619, 'train_f1': 0.6928571428571428}
# {'train_loss': 0.9049225449562073, 'train_accuracy': 0.734375, 'train_precision': 0.6754385964912281, 'train_recall': 0.6637426900584794, 'train_f1': 0.6549707602339181}
# {'train_loss': 0.8528773784637451, 'train_accuracy': 0.765625, 'train_precision': 0.6140350877192983, 'train_recall': 0.6403508771929824, 'train_f1': 0.6152046783625731}
# {'train_loss': 1.0576133728027344, 'train_accuracy': 0.6875, 'train_precision': 0.5909090909090909, 'train_recall': 0.5863636363636363, 'train_f1': 0.5746753246753247}
# {'train_loss': 1.0587412118911743, 'train_accuracy': 0.734375, 'train_precision': 0.6428571428571429, 'train_recall': 0.6607142857142857, 'train_f1': 0.6369047619047619}
# {'train_loss': 1.1523998975753784, 'train_accuracy': 0.734375, 'train_precision': 0.611111111111111, 'train_recall': 0.6166666666666667, 'train_f1': 0.6033333333333334}
# {'train_loss': 0.8556562066078186, 'train_accuracy': 0.78125, 'train_precision': 0.6636363636363637, 'train_recall': 0.6787878787878787, 'train_f1': 0.6593939393939392}
# {'train_loss': 1.2124559879302979, 'train_accuracy': 0.703125, 'train_precision': 0.6413690476190476, 'train_recall': 0.5833333333333333, 'train_f1': 0.5968537414965986}
# {'train_loss': 0.9871582388877869, 'train_accuracy': 0.703125, 'train_precision': 0.5529100529100529, 'train_recall': 0.544973544973545, 'train_f1': 0.5396825396825397}
# {'train_loss': 0.9516839981079102, 'train_accuracy': 0.703125, 'train_precision': 0.5819672131147541, 'train_recall': 0.6065573770491803, 'train_f1': 0.5841530054644809}
# {'train_loss': 0.8924190998077393, 'train_accuracy': 0.703125, 'train_precision': 0.5948275862068966, 'train_recall': 0.5804597701149425, 'train_f1': 0.5735632183908046}
# {'train_loss': 0.719356119632721, 'train_accuracy': 0.859375, 'train_precision': 0.7469135802469135, 'train_recall': 0.7592592592592593, 'train_f1': 0.745679012345679}
# {'train_loss': 0.9311286211013794, 'train_accuracy': 0.75, 'train_precision': 0.617231638418079, 'train_recall': 0.6398305084745762, 'train_f1': 0.6223163841807908}
# {'train_loss': 0.654089093208313, 'train_accuracy': 0.875, 'train_precision': 0.7456140350877193, 'train_recall': 0.7719298245614035, 'train_f1': 0.7543859649122807}
# {'train_loss': 0.8183817863464355, 'train_accuracy': 0.796875, 'train_precision': 0.7211538461538461, 'train_recall': 0.7179487179487178, 'train_f1': 0.7044871794871793}
# {'train_loss': 0.8957988619804382, 'train_accuracy': 0.78125, 'train_precision': 0.6953125, 'train_recall': 0.6744791666666666, 'train_f1': 0.6770833333333334}
# {'train_loss': 0.7309814691543579, 'train_accuracy': 0.796875, 'train_precision': 0.6964285714285714, 'train_recall': 0.7172619047619048, 'train_f1': 0.6952380952380952}
# {'train_loss': 0.8923117518424988, 'train_accuracy': 0.765625, 'train_precision': 0.6476608187134503, 'train_recall': 0.6432748538011696, 'train_f1': 0.6349206349206349}
# {'train_loss': 0.9395129084587097, 'train_accuracy': 0.765625, 'train_precision': 0.6982758620689655, 'train_recall': 0.6867816091954022, 'train_f1': 0.675287356321839}
# {'train_loss': 0.7919094562530518, 'train_accuracy': 0.796875, 'train_precision': 0.7202380952380952, 'train_recall': 0.7083333333333333, 'train_f1': 0.7054421768707483}
# {'train_loss': 0.9029900431632996, 'train_accuracy': 0.796875, 'train_precision': 0.6955128205128205, 'train_recall': 0.7288461538461538, 'train_f1': 0.6994505494505494}
# {'train_loss': 0.8249688148498535, 'train_accuracy': 0.75, 'train_precision': 0.652046783625731, 'train_recall': 0.6710526315789473, 'train_f1': 0.6477861319966584}
# {'train_loss': 0.7736033201217651, 'train_accuracy': 0.796875, 'train_precision': 0.6694915254237288, 'train_recall': 0.6949152542372882, 'train_f1': 0.6734463276836158}
# {'train_loss': 1.269476056098938, 'train_accuracy': 0.71875, 'train_precision': 0.5890804597701149, 'train_recall': 0.6077586206896551, 'train_f1': 0.5860426929392446}
# {'train_loss': 1.0620465278625488, 'train_accuracy': 0.75, 'train_precision': 0.6242424242424242, 'train_recall': 0.6757575757575757, 'train_f1': 0.6381818181818182}
# {'train_loss': 0.9550647735595703, 'train_accuracy': 0.734375, 'train_precision': 0.611111111111111, 'train_recall': 0.5916666666666667, 'train_f1': 0.5883333333333333}
# {'train_loss': 0.7819384932518005, 'train_accuracy': 0.796875, 'train_precision': 0.6694444444444444, 'train_recall': 0.65, 'train_f1': 0.6522222222222223}
# {'train_loss': 0.7842230200767517, 'train_accuracy': 0.8125, 'train_precision': 0.6764705882352942, 'train_recall': 0.6928104575163397, 'train_f1': 0.6745098039215686}
# {'train_loss': 0.9601250290870667, 'train_accuracy': 0.734375, 'train_precision': 0.6637426900584794, 'train_recall': 0.6505847953216375, 'train_f1': 0.6477861319966584}
